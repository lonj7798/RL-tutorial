# %%
import pandas as pd

# %%
import os
current_path = os.getcwd()
print("current location:", current_path)
history_path = current_path+'/history_ddpg/'
file_log = history_path+"Ant-v3/history_ddpg.txt"
# Out:
# current location: /home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco

# %%
file_log
# Out:
# '/home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco/history_ddpg/Ant-v3/history_ddpg.txt'

# %%
df = pd.read_csv("history_ddpg.txt", sep=",")

# %%
df.tail()
# Out:
#      Final Reward   Lenght  Step
# 209   -427.054018    450.0   209
# 210    -41.345978     76.1   210
# 211   -406.277830    286.6   211
# 212   -144.711551    301.7   212
# 213   -133.419582    193.0   213

# %%
df
# Out:
#      Final Reward   Lenght  Step
# 0     -221.329881    239.3     0
# 1     -296.435506    525.6     1
# 2     -169.548738    263.4     2
# 3      -50.184403    149.8     3
# 4     -107.968527    208.8     4
# ..            ...      ...   ...
# 209   -427.054018    450.0   209
# 210    -41.345978     76.1   210
# 211   -406.277830    286.6   211
# 212   -144.711551    301.7   212
# 213   -133.419582    193.0   213
#
# [214 rows x 3 columns]

# %%
df['Step'] = list(range(len(df)))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(data = df)
plt.gcf().set_size_inches(15, 8)

# %%
plt.figure(figsize = (10,30))
sns.relplot(data=df, x="Step", y="Final Reward", kind='line')
plt.show()

# %%
sns.relplot(x='Step', y='Final Reward', data = df)

# %%
df.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-79c83efb9910> in <module>
# ----> 1 df.index()
#
# TypeError: 'RangeIndex' object is not callable
