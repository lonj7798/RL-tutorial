# %% [markdown]
# ### Sequence:
# 1. Run mujoco_ddpg.py
# 2. Save the result every 10 epoch
# 3. Load the previous model
# 4. Repeat for 500 (estimated 6h)

# %%
# make the folder to save the result.
import os
current_path = os.getcwd()
print("current location:", current_path)

os.mkdir(current_path + "/" + "history_ddpg")
# Out:
# current location: /home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco

# %%
current_path += "/history_ddpg"

# %%
task = 'Ant-v3'
epoch = 2

# %%
# !python mujoco_ddpg.py --task $task --epoch 2
# Out:
# Observations shape: (111,)
# Actions shape: (8,)
# Action range: -1.0 1.0
# /home/jaewon/anaconda3/lib/python3.8/site-packages/tianshou/data/collector.py:66: UserWarning: Single environment detected, wrap to DummyVectorEnv.
#   warnings.warn("Single environment detected, wrap to DummyVectorEnv.")
# 2022-03-18 18:13:30.074389: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch #1:  99%|9| 4940/5000 [00:43<00:00, 114.37it/s, env_step=4940, len=32, los^C
# Epoch #1:  99%|9| 4941/5000 [00:43<00:00, 113.76it/s, env_step=4940, len=32, los
# Traceback (most recent call last):
#   File "mujoco_ddpg.py", line 161, in <module>
#     test_ddpg()
#   File "mujoco_ddpg.py", line 136, in test_ddpg
#     result = offpolicy_trainer(
#   File "/home/jaewon/anaconda3/lib/python3.8/site-packages/tianshou/trainer/offpolicy.py", line 156, in offpolicy_trainer
#     losses = policy.update(batch_size, train_collector.buffer)
# ...

# %%
# !python mujoco_ddpg.py --task 'Ant-v3' --epoch 2
# Out:
# Observations shape: (111,)
# Actions shape: (8,)
# Action range: -1.0 1.0
# /home/jaewon/anaconda3/lib/python3.8/site-packages/tianshou/data/collector.py:66: UserWarning: Single environment detected, wrap to DummyVectorEnv.
#   warnings.warn("Single environment detected, wrap to DummyVectorEnv.")
# 2022-03-18 18:03:13.747174: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch #1: 5001it [00:43, 114.22it/s, env_step=5000, len=12, loss/actor=-35.032, loss/critic=6.222, n/ep=0, n/st=1, rew=0.64]
# Epoch #1: test_reward: 90.421073 ± 307.697107, best_reward: 982.568459 ± 4.229930 in #0
# Epoch #2: 5001it [00:44, 111.48it/s, env_step=10000, len=155, loss/actor=-89.184, loss/critic=11.267, n/ep=0, n/st=1, rew=14.67]
# Epoch #2: test_reward: -64.774878 ± 206.455767, best_reward: 982.568459 ± 4.229930 in #0
# {'best_result': '982.57 ± 4.23',
#  'best_reward': 982.5684588949738,
#  'duration': '98.55s',
# ...

# %%
# !python mujoco_ddpg.py --task 'Ant-v3' --epoch 2 --logdir '/home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco/history_ddpg'
# Out:
# Observations shape: (111,)
# Actions shape: (8,)
# Action range: -1.0 1.0
# /home/jaewon/anaconda3/lib/python3.8/site-packages/tianshou/data/collector.py:66: UserWarning: Single environment detected, wrap to DummyVectorEnv.
#   warnings.warn("Single environment detected, wrap to DummyVectorEnv.")
# 2022-03-18 18:54:38.045492: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch #1: 5001it [00:43, 115.91it/s, env_step=5000, len=147, loss/actor=-31.865, loss/critic=4.305, n/ep=0, n/st=1, rew=50.74]
# Epoch #1: test_reward: -195.023697 ± 390.495182, best_reward: 982.568459 ± 4.229930 in #0
# Epoch #2: 5001it [00:43, 114.11it/s, env_step=10000, len=42, loss/actor=-75.567, loss/critic=6.959, n/ep=0, n/st=1, rew=-21.99]
# Epoch #2: test_reward: -170.721650 ± 236.383338, best_reward: 982.568459 ± 4.229930 in #0
# {'best_result': '982.57 ± 4.23',
#  'best_reward': 982.5684588949738,
#  'duration': '96.76s',
# ...

# %%
reuse = '~/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco/history_ddpg/Ant-v3/ddpg/seed_0_0318_185437-Ant_v3_ddpg/policy.pth'

# %%
# !python mujoco_ddpg.py --task 'Ant-v3' --epoch 10 --logdir '/home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco/history_ddpg' --resume-path $reuse
# Out:
# Observations shape: (111,)
# Actions shape: (8,)
# Action range: -1.0 1.0
# Loaded agent from:  /home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco/history_ddpg/Ant-v3/ddpg/seed_0_0318_185437-Ant_v3_ddpg/policy.pth
# /home/jaewon/anaconda3/lib/python3.8/site-packages/tianshou/data/collector.py:66: UserWarning: Single environment detected, wrap to DummyVectorEnv.
#   warnings.warn("Single environment detected, wrap to DummyVectorEnv.")
# 2022-03-18 19:04:38.019645: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch #1: 5001it [00:42, 117.36it/s, env_step=5000, len=1000, loss/actor=-31.908, loss/critic=5.171, n/ep=0, n/st=1, rew=-604.70]
# Epoch #1: test_reward: 91.783776 ± 262.229060, best_reward: 982.568459 ± 4.229930 in #0
# Epoch #2: 5001it [00:44, 112.23it/s, env_step=10000, len=129, loss/actor=-82.228, loss/critic=10.551, n/ep=0, n/st=1, rew=31.17]
# ...

# %%
--resume-path

# %%
log = current_path+'/log/'

# %%
log
# Out:
# '/home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco/history_ddpg/log/'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'README.md',
#  'plotter.py',
#  'analysis.py',
#  'history_ddpg',
#  'mujoco_trpo.py',
#  'mujoco_td3.py',
#  'mujoco_sac.py',
#  'log',
#  'benchmark',
#  'gen_json.py',
#  'Untitled.ipynb',
#  'mujoco_npg.py',
#  'mujoco_reinforce.py',
#  'run_experiments.sh',
#  'mujoco_ddpg_repeat.py',
#  'mujoco_a2c.py',
#  'mujoco_ppo.py',
#  'mujoco_ddpg.py',
#  'tools.py']

# %%
current_path
# Out:
# '/home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco/history_ddpg'

# %%
current_path = os.getcwd()

# %%
current_path
# Out:
# '/home/jaewon/MyWork/RL-tutorial/Ant_v3/tianshou-master/examples/mujoco'

# %%
model = torch.load(PATH)
model.eval()

# %%
model = torch.load(current_path+'/policy2.pth')

# %%
model
# Out:
# OrderedDict([('actor.preprocess.model.model.0.weight',
#               tensor([[-0.0007,  0.0509, -0.0781,  ..., -0.0052,  0.0143, -0.0389],
#                       [ 0.0563, -0.0578,  0.0861,  ..., -0.0770, -0.0068,  0.0939],
#                       [ 0.0343,  0.0027, -0.0823,  ..., -0.0787, -0.0816,  0.0947],
#                       ...,
#                       [-0.0819, -0.0440, -0.0471,  ..., -0.0207,  0.0386,  0.0824],
#                       [ 0.0364, -0.0778,  0.0823,  ..., -0.0100, -0.0940,  0.0157],
#                       [-0.0805, -0.0853, -0.0320,  ..., -0.0666,  0.0938,  0.0071]],
#                      device='cuda:0')),
#              ('actor.preprocess.model.model.0.bias',
#               tensor([-0.0641,  0.0843, -0.0282, -0.0448, -0.0011,  0.0255,  0.0596, -0.0669,
#                        0.0598,  0.0744,  0.0124,  0.0721,  0.0155,  0.0446,  0.0110, -0.0821,
#                        0.0125,  0.0078, -0.0300, -0.0209, -0.0858, -0.0292, -0.0386,  0.0354,
# ...
